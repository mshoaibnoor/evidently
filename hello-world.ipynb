# %%
import pandas as pd

from sklearn import datasets

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset, DataDriftTestPreset

from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

iris_data = datasets.load_iris(as_frame='auto')
iris_frame = iris_data.frame

# %%
data_stability= TestSuite(tests=[
    DataStabilityTestPreset(),
])
data_stability.run(current_data=iris_frame.iloc[:60], reference_data=iris_frame.iloc[60:], column_mapping=None)
data_stability
# Out:
# /home/shoaib/mlflow/lib/python3.10/site-packages/evidently/metrics/data_integrity/dataset_missing_values_metric.py:165: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_a6f6fc889a7a4ad6bfafae79f565a31a = {"name": "Test Suite", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "7775452a-a324-4cea-888e-431eee5be8fe", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "16", "label": "Tests"}, {"value": "9", "label": "Success"}, {"value": "0", "label": "Warning"}, {"value": "7", "label": "Fail"}, {"value": "0", "label": "Error"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "test_suite", "title": "", "size": 2, "id": "70423d21-4331-4160-8478-1b45c629d993", "details": "", "alertsPosition": null, "alertStats": null, "params": {"tests": [{"title": "Number of Rows", "description": "The number of rows is 60. The test threshold is eq=90 \u00b1 9.", "state": "fail", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "Number of Rows"}}, {"title": "Number of Columns", "description": "The number of columns is 5. The test threshold is eq=5.", "state": "success", "details": {"parts": [{"id": "number_of_column", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Number of Columns"}}, {"title": "Column Types", "description": "The number of columns with a type mismatch is 0 out of 5.", "state": "success", "details": {"parts": [{"id": "63b6dfd1-83d6-4391-bfa1-f8bb83285bb3", "title": "", "type": "widget"}]}, "groups": {"test_group": "data_integrity", "test_type": "Column Types"}}, {"title": "The Share of Missing Values in a Column", "description": "The share of missing values in the column **petal length (cm)** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Missing Values in a Column"}}, {"title": "The Share of Missing Values in a Column", "description": "The share of missing values in the column **petal width (cm)** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Missing Values in a Column"}}, {"title": "The Share of Missing Values in a Column", "description": "The share of missing values in the column **sepal length (cm)** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Missing Values in a Column"}}, {"title": "The Share of Missing Values in a Column", "description": "The share of missing values in the column **sepal width (cm)** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Missing Values in a Column"}}, {"title": "The Share of Missing Values in a Column", "description": "The share of missing values in the column **target** is 0. The test threshold is lte=0 \u00b1 1e-12.", "state": "success", "details": {"parts": []}, "groups": {"test_group": "data_integrity", "test_type": "The Share of Missing Values in a Column"}}, {"title": "Share of Out-of-Range Values", "description": "The share of values out of range in the column **petal length (cm)** is 0.833 (50 out of 60).  The test threshold is eq=0 \u00b1 1e-12.", "state": "fail", "details": {"parts": [{"id": "2a3cc7ab-f284-415e-8201-6fc7fb891546", "title": "Share of Out-of-Range Values for petal length (cm)", "type": "widget"}]}, "groups": {"by_feature": "petal length (cm)", "test_group": "data_quality", "test_type": "Share of Out-of-Range Values"}}, {"title": "Share of Out-of-Range Values", "description": "The share of values out of range in the column **petal width (cm)** is 0.833 (50 out of 60).  The test threshold is eq=0 \u00b1 1e-12.", "state": "fail", "details": {"parts": [{"id": "e5a8ffba-06c6-4c56-a33f-59b08c8bbc1e", "title": "Share of Out-of-Range Values for petal width (cm)", "type": "widget"}]}, "g ...

# %%
data_drift_test_suite = TestSuite(tests=[
   DataDriftTestPreset(),
])
 
data_drift_test_suite.run(reference_data=ref, current_data=curr)
data_drift_test_suite
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 data_drift_test_suite = TestSuite(tests=[
# ----> 2    DataDriftTestPreset(),
#       3 ])
#       5 data_drift_test_suite.run(reference_data=ref, current_data=curr)
#       6 data_drift_test_suite
#
# NameError: name 'DataDriftTestPreset' is not defined

# %%
data_drift_report = Report(metrics=[
    DataDriftPreset(),
])

data_drift_report.run(current_data=iris_frame.iloc[:60], reference_data=iris_frame.iloc[60:], column_mapping=None)
data_drift_report
# Out:
# /home/shoaib/mlflow/lib/python3.10/site-packages/scipy/stats/_stats_py.py:7407: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /home/shoaib/mlflow/lib/python3.10/site-packages/scipy/stats/_stats_py.py:7407: RuntimeWarning:
#
# divide by zero encountered in divide
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_6e179463f89e49fba6a9504bc16c5459 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "6550b3fa-7f8b-49fd-abbe-073a33b88e4d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "Dataset Drift", "label": "Dataset Drift is detected. Dataset drift detection threshold is 0.5"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "996de189-47b9-49d8-a832-7bbcee446ed7", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "5", "label": "Columns"}, {"value": "5", "label": "Drifted Columns"}, {"value": "1.0", "label": "Share of Drifted Columns"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "2449b3a9-d807-4a4e-b047-d98e5ea74da7", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Drift Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "big_table", "title": "Drift is detected for 100.0% of columns (5 out of 5).", "size": 2, "id": "5de5e9a4-8df5-41bb-86cc-d57a2891ee3a", "details": "", "alertsPosition": "row", "alertStats": null, "params": {"rowsPerPage": 5, "columns": [{"title": "Column", "field": "column_name"}, {"title": "Type", "field": "column_type"}, {"title": "Reference Distribution", "field": "reference_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Current Distribution", "field": "current_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Data Drift", "field": "data_drift"}, {"title": "Stat Test", "field": "stattest_name"}, {"title": "Drift Score", "field": "drift_score"}], "data": [{"details": {"parts": [{"title": "DATA DISTRIBUTION", "id": "0f2d2347-171d-4db0-86c2-6cc23fe56351", "type": "widget"}]}, "column_name": "target", "column_type": "cat", "stattest_name": "chi-square p_value", "reference_distribution": {"x": [0, 1, 2], "y": [0, 40, 50]}, "current_distribution": {"x": [0, 1, 2], "y": [50, 10, 0]}, "data_drift": "Detected", "drift_score": 0.0}, {"details": {"parts": [{"title": "DATA DRIFT", "id": "1d8f9ce4-11af-4d8b-8334-bbb73d6ac1dd", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "252d4ee8-743c-45f4-bf86-a998e93f0a0e", "type": "widget"}]}, "column_name": "sepal width (cm)", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [2.0, 2.18, 2.36, 2.54, 2.7199999999999998, 2.9, 3.08, 3.26, 3.44, 3.62, 3.8], "y": [0.06172839506172834, 0.30864197530864246, 0.6172839506172834, 0.8024691358024705, 0.7407407407407401, 1.7283950617283936, 0.7407407407407419, 0.3703703703703701, 0.06172839506172834, 0.12345679012345698]}, "current_distribution": {"x": [2.3, 2.51, 2.7199999999999998, 2.9299999999999997, 3.14, 3.35, 3.56, 3.7700000000000005, 3.9800000000000004, 4.19, 4.4], "y": [0.23809523809523814, 0.07936507936507937, 0.3174603174603175, 0.8730158730158714, 0.7936507936507938, 1.1904761904761907, 0.4761904761904753, 0.4761904761904763, 0.15873015873015875, 0.15873015873015875]}, "data_drift": "Detected", "drift_score": 0.0}, {"details": {"parts": [{"title": "DATA DRIFT", "id": "ea58b210-3c84-4dde-8b98-de8657c85ba7", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "0362aae3-7c50-4c1a-99dd-6f9a513841a9", "type": "widget"}]}, "column_name": "sepal length (cm)", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [4.9, 5.2, 5.5, 5.800000000000001, 6.1000000000000005, 6.4, 6.7, 7.0, 7.300000000000001, 7.6, 7.9], "y": [0.14814814814814822, 0.037037037037037056, 0.7777777777777759, 0.5555555555555559, 0.4444444444444447, 0.4074074074074076, 0.5185185185185188, 0.18518518518518476, 0.03703703703703717, 0.2222222222222217]}, "current_distributi ...
#     var additional_graphs_evidently_dashboard_6e179463f89e49fba6a9504bc16c5459 = {"0f2d2347-171d-4db0-86c2-6cc23fe56351": {"type": "big_graph", "title": "", "size": 2, "id": "0f2d2347-171d-4db0-86c2-6cc23fe56351", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "visible": true, "x": [0, 1], "y": [50, 10], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#ed0400"}, "name": "current", "visible": false, "x": [0, 1], "y": [83.33333333333334, 16.666666666666664], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "visible": true, "x": [2, 1], "y": [50, 40], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "visible": false, "x": [2, 1], "y": [55.55555555555556, 44.44444444444444], "type": "bar", "xaxis": "x", "yaxis": "y"}], "layout": {"template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth":
